# %%
import numpy as np
import pandas as pd
from pathlib import Path

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 2.4.6
# Pandas: 3.0.5

# %%
DATA_PATH = Path("../data/raw/WEC_Simulation_Data.csv")

df = pd.read_csv(DATA_PATH)

print("Dataset shape:", df.shape)
# Out:
# Dataset shape: (450900, 19)

# %%
print(df.columns.tolist())
df.head()
# Out:
# ['l1', 'd1', 'd2', 'a1', 'm1', 'Qi', 'w1', 'w2', 'B', 'P_ext', 'eta_maxx', 'P_ext_plate', 'P_ext_rel_error', 'xi1_rms', 'xi2_rms', 'REFL', 'TRANS', 'chi', 'P_inc']
#    l1   d1   d2   a1  m1    Qi        w1        w2          B       P_ext  \
# 0  10  1.0  1.5  0.0   1  4.00  0.148368  0.148368  10.296736  121.429417
# 1  10  1.0  1.5  0.0   1  4.01  0.148368  0.148368  10.296736  131.331285
# 2  10  1.0  1.5  0.0   1  4.02  0.148368  0.148368  10.296736  142.341292
# 3  10  1.0  1.5  0.0   1  4.03  0.148368  0.148368  10.296736  154.619917
# 4  10  1.0  1.5  0.0   1  4.04  0.148368  0.148368  10.296736  168.359488
#
#    eta_maxx  P_ext_plate  P_ext_rel_error   xi1_rms   xi2_rms      REFL  \
# 0  0.007275   669.850584         4.516378  0.895059  0.867017  0.006090
# 1  0.007842   700.988869         4.337562  0.903243  0.876980  0.006239
# 2  0.008471   736.552365         4.174552  0.912409  0.888063  0.006384
# 3  0.009171   777.194664         4.026485  0.922690  0.900410  0.006526
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 450900 entries, 0 to 450899
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   l1               450900 non-null  int64
#  1   d1               450900 non-null  float64
#  2   d2               450900 non-null  float64
#  3   a1               450900 non-null  float64
#  4   m1               450900 non-null  int64
#  5   Qi               450900 non-null  float64
#  6   w1               450900 non-null  float64
#  7   w2               450900 non-null  float64
#  8   B                450900 non-null  float64
#  9   P_ext            450900 non-null  float64
#  10  eta_maxx         450900 non-null  float64
#  11  P_ext_plate      450900 non-null  float64
#  12  P_ext_rel_error  450900 non-null  float64
#  13  xi1_rms          450900 non-null  float64
#  14  xi2_rms          450900 non-null  float64
#  15  REFL             450900 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                     count          mean           std           min  \
# l1               450900.0  2.000000e+01  7.071076e+00  1.000000e+01
# d1               450900.0  1.500000e+00  4.082487e-01  1.000000e+00
# d2               450900.0  2.000000e+00  4.082487e-01  1.500000e+00
# a1               450900.0  7.500000e-01  5.590176e-01  0.000000e+00
# m1               450900.0  3.000000e+00  1.414215e+00  1.000000e+00
# Qi               450900.0  6.500000e+00  1.446261e+00  4.000000e+00
# w1               450900.0  1.396405e-01  7.126008e-03  1.309130e-01
# w2               450900.0  1.396405e-01  7.126008e-03  1.309130e-01
# B                450900.0  2.027928e+01  7.071090e+00  1.026183e+01
# P_ext            450900.0 -3.638102e+03  4.638044e+05 -1.121170e+08
# eta_maxx         450900.0 -9.864046e-02  1.249542e+01 -3.020097e+03
# P_ext_plate      450900.0  1.308594e+06  1.621486e+08  1.326076e+02
# P_ext_rel_error  450900.0  1.417150e+02  6.347425e+03  2.394196e+00
# ...

# %%
missing = df.isnull().sum()

print(missing)
# Out:
# l1                 0
# d1                 0
# d2                 0
# a1                 0
# m1                 0
# Qi                 0
# w1                 0
# w2                 0
# B                  0
# P_ext              0
# eta_maxx           0
# P_ext_plate        0
# P_ext_rel_error    0
# xi1_rms            0
# xi2_rms            0
# REFL               0
# TRANS              0
# chi                0
# P_inc              0
# dtype: int64

# %%
duplicates = df.duplicated().sum()

print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 0

# %%
FEATURES = [
    "l1",
    "d1",
    "d2",
    "a1",
    "m1",
    "Qi"
]

TARGET = "P_ext"

X = df[FEATURES].copy()
y = df[TARGET].copy()

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# Features:
#    l1   d1   d2   a1  m1    Qi
# 0  10  1.0  1.5  0.0   1  4.00
# 1  10  1.0  1.5  0.0   1  4.01
# 2  10  1.0  1.5  0.0   1  4.02
# 3  10  1.0  1.5  0.0   1  4.03
# 4  10  1.0  1.5  0.0   1  4.04
#
# Target:
# 0    121.429417
# 1    131.331285
# 2    142.341292
# 3    154.619917
# 4    168.359488
# Name: P_ext, dtype: float64

# %%
X.describe().T
# Out:
#        count   mean       std   min     25%    50%     75%   max
# l1  450900.0  20.00  7.071076  10.0  15.000  20.00  25.000  30.0
# d1  450900.0   1.50  0.408249   1.0   1.000   1.50   2.000   2.0
# d2  450900.0   2.00  0.408249   1.5   1.500   2.00   2.500   2.5
# a1  450900.0   0.75  0.559018   0.0   0.375   0.75   1.125   1.5
# m1  450900.0   3.00  1.414215   1.0   2.000   3.00   4.000   5.0
# Qi  450900.0   6.50  1.446261   4.0   5.250   6.50   7.750   9.0

# %%
y.describe()
# Out:
# count    4.509000e+05
# mean    -3.638102e+03
# std      4.638044e+05
# min     -1.121170e+08
# 25%      3.003622e+01
# 50%      1.258041e+02
# 75%      4.716507e+02
# max      1.515276e+04
# Name: P_ext, dtype: float64

# %%
print("Minimum P_ext:", y.min())
print("Maximum P_ext:", y.max())
print("Mean P_ext:", y.mean())
print("Median P_ext:", y.median())
# Out:
# Minimum P_ext: -112117019.928368
# Maximum P_ext: 15152.7597816109
# Mean P_ext: -3638.1024564209574
# Median P_ext: 125.80414414577601

# %%
print("Negative P_ext:", (y < 0).sum())
print("Zero P_ext:", (y == 0).sum())
print("NaN P_ext:", y.isna().sum())
print("Infinite P_ext:", np.isinf(y).sum())
# Out:
# Negative P_ext: 87539
# Zero P_ext: 0
# NaN P_ext: 0
# Infinite P_ext: 0
